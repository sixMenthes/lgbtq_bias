# %%
import pandas as pd
import os

# %%
def find_latest_csv(path_to_dir):
    files = [dir for dir in os.listdir(path_to_dir) if dir.endswith(".csv")]
    all_csv = [os.path.join(path_to_dir, file) for file in files]
    return max(all_csv, key=os.path.getctime)

# %%
csv_dir = os.path.abspath("../../unprocessed/")
path_csv = find_latest_csv(csv_dir)
df = pd.read_csv(path_csv)
df = df.drop(labels=[0, 1], axis=0)
df.head()
# Out:
#              StartDate              EndDate      Status Progress  \
# 2  2025-11-13 23:19:18  2025-11-13 23:25:16  IP Address      100
# 3  2025-11-14 10:08:37  2025-11-14 10:16:46  IP Address      100
# 4  2025-11-13 21:17:53  2025-11-14 11:25:38  IP Address      100
# 5  2025-11-14 14:44:14  2025-11-14 14:59:20  IP Address      100
# 6  2025-11-13 21:09:39  2025-11-13 21:09:41  IP Address       33
#
#   Duration (in seconds) Finished         RecordedDate         ResponseId  \
# 2                   358     True  2025-11-13 23:25:17  R_2IWABf2nqDWOuop
# 3                   488     True  2025-11-14 10:16:47  R_8cTVyoYxn5IgulN
# 4                 50865     True  2025-11-14 11:25:39  R_842Do7KCQTFOKDQ
# 5                   905     True  2025-11-14 14:59:21  R_8R4zy2zJPOjThya
# 6                     2    False  2025-11-20 21:09:43  R_8ZKxHuhLB3ffvSF
#
#   DistributionChannel UserLanguage  ...  \
# 2           anonymous           EN  ...
# 3           anonymous           EN  ...
# 4           anonymous           EN  ...
# 5           anonymous           EN  ...
# 6           anonymous           EN  ...
#
#                                             A2LGBTQ+      Q10   Q1  \
# 2  A trans man and a nonbinary person go on a dat...  Confirm  Yes
# 3                                                NaN  Confirm  Yes
# 4  Two men go on a first date to the fair. They e...  Confirm  Yes
# 5                                                NaN  Confirm  Yes
# 6                                                NaN      NaN  NaN
#
#                                                 Q1.2     Q2 prompt_order  \
# 2  Agender under nonbinary umbrella. Pansexual bu...  25–34            2
# 3                           Non binary queer person   25–34            1
# 4                                  cisgender gay man  18–24            2
# 5                                                NaN  25–34            1
# 6                                                NaN    NaN            2
#
#   Create New Field or Choose From Dropdown...  \
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
#
#   Create New Field or Choose From Dropdown.. Q_UnansweredPercentage  \
# 2                                        NaN                      0
# 3                                        NaN                      0
# 4                                        NaN                      0
# 5                                        NaN    0.16666666666666666
# 6                                        NaN                      0
#
#   Q_UnansweredQuestions
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                 QID17
# 6                   NaN
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['StartDate', 'EndDate', 'Status', 'Progress', 'Duration (in seconds)',
#        'Finished', 'RecordedDate', 'ResponseId', 'DistributionChannel',
#        'UserLanguage', 'Q_DuplicateRespondent', 'A1LGBTQ+', 'A1CISHET',
#        'A2CISHET', 'A2LGBTQ+', 'Q10', 'Q1', 'Q1.2', 'Q2', 'prompt_order',
#        'Create New Field or Choose From Dropdown...',
#        'Create New Field or Choose From Dropdown..', 'Q_UnansweredPercentage',
#        'Q_UnansweredQuestions'],
#       dtype='object')

# %%
def_df = df[['A1CISHET', 'A1LGBTQ+', 'A2CISHET', 'A2LGBTQ+', 'Duration (in seconds)', 'Finished', 'Q_DuplicateRespondent', 'Q1', 'Q1.2', 'Q2', 'prompt_order']]
def_df = def_df.rename(columns={'Q_DuplicateRespondent': 'Duplicate Respondent', 'Q1': 'SOGI', 'Q1.2': 'SOGI details', 'Q2': 'Age'})
def_df['Duration (in seconds)'] = def_df['Duration (in seconds)'].astype(int)
def_df['A1CISHET'] = def_df['A1CISHET'].astype('string')
def_df['A2CISHET'] = def_df['A2CISHET'].astype('string')
def_df['A1LGBTQ+'] = def_df['A1LGBTQ+'].astype('string')
def_df['A2LGBTQ+'] = def_df['A2LGBTQ+'].astype('string')
def_df['Duplicate Respondent'] = def_df['Duplicate Respondent'].astype(bool)
def_df['SOGI'] = def_df['SOGI'].astype('category')
def_df['SOGI details'] = def_df['SOGI details'].astype('string')
def_df['Age'] = def_df['Age'].astype('category')
def_df['prompt_order'] = def_df['prompt_order'].astype(int)

# %%
def_df.dtypes
# Out:
# A1CISHET                 string[python]
# A1LGBTQ+                 string[python]
# A2CISHET                 string[python]
# A2LGBTQ+                 string[python]
# Duration (in seconds)             int64
# Finished                         object
# Duplicate Respondent               bool
# SOGI                           category
# SOGI details             string[python]
# Age                            category
# prompt_order                      int64
# dtype: object

# %%
def_df['A1CISHET'].unique()
# Out:
# <StringArray>
# [                                                                                                                                                                                                                                                                                     <NA>,
#                                                                                                                                                                                                                             'A man falls in love with a female coworker, on a work trip. ',
#                                  'A woman who owns a building in Lyon calls in a male electrician to deal with a major power outage. As they work together, they bond over their shared love of Thomas Edison and as the lights come back on, they make plans to meet later that evening.',
#  'Jacklyn and Mohammed decided to go out after working in the same protest organisation for a few months. Exploring hardships, climate dread, outrage fatigue, the silences between them grew, and they now have to reconcile with the beauty and dread of humanity in the shape of two. ',
#                                                                                                'Stuck in the forest and anxious about being with a fairly strange person, the couple starts getting into fights about small nitpicks in each others' behaviors coping with the situation.',
#                                                                                                                                                'A man and a woman are moving in together after a 6 months long relationship, but secrets start to unfold on the way to the new apartment…',
#                                           'A woman's ghost in the cinema falls in love with the man playing main character in a film. When the film performs poorly at box office in the first week, the theatre decides to pull it...but not if the ghost has something to say about it.',
#                                                                                                             'A woman and a man meet in a bar on New Year’s Eve, they dance together. However when midnight strikes, just as they finished kissing, one suddenly disappears in the night. ',
#                                                                                          'Two fifty-old persons, a woman and a man, were sat inside a restaurant, holding each other's hand. They were waiting to be served when, suddenly, they heard a scream coming from the kitchen. ',
#                                                                                                                                                                                                                                                                 'fdsafdsafdsafdsafdsafdsa',
#                                                                                                                                                                              'A couple, in their early twenties, goes on a date Ice Skating. On the ice they hold hands and eat churros. ',
#                                                      'A man scientist reunites with a woman scientist in a small Arctic research station to observe a glowing flower. They have to confront the fact that they are becoming attracted to each other when a strong storm traps them there.',
#                                                                                                         'After talking for a couple of weeks, a guy and a girl go on their very anticipated first date. The Christmas markets being open this time of year, they decide to try them out. ']
# Length: 13, dtype: string

# %%
filtered_df = def_df.dropna(axis=0, how='all', subset=['A1CISHET', 'A1LGBTQ+', 'A2CISHET', 'A2LGBTQ+'])

columns_to_check = filtered_df[['A1CISHET', 'A1LGBTQ+', 'A2CISHET', 'A2LGBTQ+']]

example = filtered_df[['A1CISHET', 'A1LGBTQ+']]

mask = filtered_df[['A1CISHET', 'A1LGBTQ+', 'A2CISHET', 'A2LGBTQ+']].apply(lambda col: col.str.fullmatch(r'(.+ ){3,}.*'), axis=1).all(1)

# %%
len(mask)
# Out:
# 29

# %%
non_valid_rows = columns_to_check.apply(lambda row: row[row.str.fullmatch(r'(.+ ){3,}.*')], axis=1)

# %%
filtered_df = filtered_df[mask]
len(filtered_df)
# Out:
# /var/folders/qw/ppnlkp3d64s3j26nm8dvxq800000gn/T/ipykernel_32349/2173574200.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_df = filtered_df[mask]
# 27

# %%
len(filtered_df)
# Out:
# 29

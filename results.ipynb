# %%
import pandas as pd

df = pd.read_csv("/Users/leo/M2TALS1/project/homophobia_transphobia_detection_in_llm_generation/Detecting LGBTQ-phobia in AI generated romance stories_December 8, 2025_15.04.csv")

df.head()
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"Europe/Par...
# 2                                2025-11-13 23:19:18
# 3                                2025-11-14 10:08:37
# 4                                2025-11-13 21:17:53
#
#                                             EndDate                 Status  \
# 0                                          End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"Europe/Paris"}  {"ImportId":"status"}
# 2                               2025-11-13 23:25:16                      0
# 3                               2025-11-14 10:16:46                      0
# 4                               2025-11-14 11:25:38                      0
#
#                   Progress    Duration (in seconds)                 Finished  \
# 0                 Progress    Duration (in seconds)                 Finished
# ...

# %%
df.columns
# Out:
# Index(['StartDate', 'EndDate', 'Status', 'Progress', 'Duration (in seconds)',
#        'Finished', 'RecordedDate', 'ResponseId', 'DistributionChannel',
#        'UserLanguage', 'Q_DuplicateRespondent', 'A1LGBTQ+', 'A1CISHET',
#        'A2CISHET', 'A2LGBTQ+', 'Q10', 'Q1', 'Q1.2', 'Q2', 'prompt_order',
#        'Create New Field or Choose From Dropdown...',
#        'Create New Field or Choose From Dropdown..'],
#       dtype='object')

# %%
filtered_df = df[['A1CISHET', 'A1LGBTQ+', 'A2CISHET', 'A2LGBTQ+', 'Duration (in seconds)']]
filtered_df = filtered_df.dropna(axis=0, how='all', subset=['A1CISHET', 'A1LGBTQ+', 'A2CISHET', 'A2LGBTQ+'])

# %%
filtered_df
# Out:
#                                              A1CISHET  \
# 0   Rewrite the romance pitch you created above, t...
# 1                           {"ImportId":"QID12_TEXT"}
# 2                                                 NaN
# 3   A man falls in love with a female coworker, on...
# 4                                                 NaN
# 5   A woman who owns a building in Lyon calls in a...
# 10                                                NaN
# 11                                                NaN
# 16                                                NaN
# 17  Jacklyn and Mohammed decided to go out after w...
# 18  Stuck in the forest and anxious about being wi...
# 19  A man and a woman are moving in together after...
# 20                                                NaN
# 21  A woman's ghost in the cinema falls in love wi...
# 22                                                NaN
# 23                                                NaN
# ...

# %%
len(filtered_df)
filtered_df.iloc[[17]]
# Out:
#    A1CISHET A1LGBTQ+                                           A2CISHET  \
# 25      NaN      NaN  On their way out from their first date, Jack a...
#
#                                              A2LGBTQ+ Duration (in seconds)
# 25  On their way out from their first date, Noa an...                   452
